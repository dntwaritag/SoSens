# %% [markdown]
# # Soil Quality Monitoring and Crop Recommendation System for Rwanda
# # Capstone Project: Climate-Smart Agriculture Decision Support
# # Author: Denys Ntwaritaganzwa
# # Date: November 2025

# %% [markdown]
# ## 1. Title & Problem Definition
# PROBLEM STATEMENT:
# This notebook develops a machine learning model to predict suitable crops based on soil
# and environmental conditions in Rwanda. The system aims to provide smallholder farmers
# with data-driven recommendations to improve agricultural productivity.
#
# RESEARCH OBJECTIVES:
# - Identify soil parameters (pH, N, P, K, moisture) that influence crop suitability
# - Develop ML models to classify crop recommendations based on soil health
# - Provide actionable insights for farmers in rural Rwanda
#
# Target Crops: Focus on crops commonly grown in Rwanda (beans, maize, cassava,
# potatoes, wheat, rice, sorghum, banana)

# %% [markdown]
# ## 2. Import Required Libraries

# %%
# Data manipulation and analysis
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.utils import resample

# Machine Learning Models
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# Model Evaluation
from sklearn.metrics import (classification_report, confusion_matrix,
                             accuracy_score, precision_recall_fscore_support,
                             roc_auc_score, roc_curve)

# Hyperparameter Tuning
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# Model Saving
import joblib
import pickle

# Warnings suppression
import warnings
warnings.filterwarnings('ignore')

# Display settings
pd.set_option('display.max_columns', None)
plt.style.use('seaborn-v0_8-darkgrid')

print(" All libraries imported successfully")
# Out:
#  All libraries imported successfully

# %% [markdown]
# ## 3. Data Loading & Inspection

# %%
# Load the dataset
df = pd.read_csv('/content/Crop Recommendation using Soil Properties and Weather Prediction.csv')

print("="*80)
print("DATASET OVERVIEW")
print("="*80)
print(f"\nDataset Shape: {df.shape}")
print(f"Total Records: {df.shape[0]:,}")
print(f"Total Features: {df.shape[1]}")
# Out:
# ...
# DATASET OVERVIEW
# ...
#
# Dataset Shape: (3867, 29)
# Total Records: 3,867
# Total Features: 29

# %%
# Display first few rows
print("\n" + "="*80)
print("SAMPLE DATA (First 5 rows)")
print("="*80)
df.head()
# Out:
# ...
# SAMPLE DATA (First 5 rows)
# ...
#          Soilcolor    Ph        K       P     N        Zn       S    QV2M-W  \
# 0  Yellowish brown  5.81  738.231   5.401  0.23  2.976000  13.816  7.993333
# 1  Yellowish brown  5.43  606.382  10.478  0.23  3.077000  16.421  7.993333
# 2            brown  5.41  386.580   6.847  0.23  6.611000  16.557  7.993333
# 3              red  5.65  207.086   3.418  0.23  0.460181  16.075  7.993333
# 4              red  5.27  317.357  39.282  0.23  2.743000  12.558  7.993333
#
#      QV2M-Sp    QV2M-Su   QV2M-Au  T2M_MAX-W  T2M_MAX-Sp  T2M_MAX-Su  \
# 0  10.456667  11.963333  9.683333  26.853333   28.526667       23.06
# 1  10.456667  11.963333  9.683333  26.853333   28.526667       23.06
# 2  10.456667  11.963333  9.683333  26.853333   28.526667       23.06
# 3  10.456667  11.963333  9.683333  26.853333   28.526667       23.06
# 4  10.456667  11.963333  9.683333  26.853333   28.526667       23.06
#
# ...

# %%
# Display basic information
print("\n" + "="*80)
print("DATASET INFORMATION")
print("="*80)
df.info()
# Out:
# ...
# DATASET INFORMATION
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3867 entries, 0 to 3866
# Data columns (total 29 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Soilcolor       3867 non-null   object
#  1   Ph              3867 non-null   float64
#  2   K               3867 non-null   float64
#  3   P               3867 non-null   float64
#  4   N               3867 non-null   float64
#  5   Zn              3867 non-null   float64
#  6   S               3867 non-null   float64
#  7   QV2M-W          3867 non-null   float64
#  8   QV2M-Sp         3867 non-null   float64
#  9   QV2M-Su         3867 non-null   float64
#  10  QV2M-Au         3867 non-null   float64
#  11  T2M_MAX-W       3867 non-null   float64
#  12  T2M_MAX-Sp      3867 non-null   float64
#  13  T2M_MAX-Su      3867 non-null   float64
#  14  T2M_MAX-Au      3867 non-null   float64
#  15  T2M_MIN-W       3867 non-null   float64
# ...

# %%
# Check for missing values
print("\n" + "="*80)
print("MISSING VALUES ANALYSIS")
print("="*80)
missing_data = df.isnull().sum()
missing_percent = (missing_data / len(df)) * 100
missing_df = pd.DataFrame({
    'Missing Count': missing_data,
    'Percentage': missing_percent
})
print(missing_df[missing_df['Missing Count'] > 0].sort_values('Missing Count', ascending=False))

if missing_df['Missing Count'].sum() == 0:
    print(" No missing values detected")
# Out:
# ...
# MISSING VALUES ANALYSIS
# ...
# Empty DataFrame
# Columns: [Missing Count, Percentage]
# Index: []
#  No missing values detected

# %%
# Statistical summary
print("\n" + "="*80)
print("STATISTICAL SUMMARY")
print("="*80)
print(df.describe())
# Out:
# ...
# STATISTICAL SUMMARY
# ...
#                 Ph            K            P            N           Zn  \
# count  3867.000000  3867.000000  3867.000000  3867.000000  3867.000000
# mean      5.857295   324.284770    11.349588     0.179153     1.774094
# std       0.676690   202.250133    34.141864     0.066476     1.460809
# min       4.300000    41.134000     0.000000     0.000262     0.100000
# 25%       5.390000   191.000000     2.000000     0.131200     1.100000
# 50%       5.780000   282.000000     4.000000     0.179884     1.500000
# 75%       6.200000   405.000000     7.920000     0.230000     2.060000
# max       8.500000  2119.000000   782.000000     0.695600    45.500000
#
#                  S       QV2M-W      QV2M-Sp      QV2M-Su      QV2M-Au  \
# count  3867.000000  3867.000000  3867.000000  3867.000000  3867.000000
# mean     11.311625     8.346870     9.082508    12.232020    10.990747
# std       5.542094     0.613948     0.790654     0.894970     0.993861
# ...

# %% [markdown]
# ## 4. Crop Filtering for Rwanda Context

# %%
# Crops commonly grown in Rwanda based on agricultural research
RWANDA_CROPS = [
    'Beans', 'Bean', 'Maize', 'Corn', 'Cassava', 'Potato', 'Potatoes',
    'Wheat', 'Rice', 'Sorghum', 'Banana', 'Plantain', 'Sweet Potato',
    'Peas', 'Groundnut', 'Soybean', 'Coffee', 'Tea'
]

print("="*80)
print("FILTERING CROPS RELEVANT TO RWANDA")
print("="*80)

# Check current crop distribution
print("\nOriginal Crop Distribution:")
print(df['label'].value_counts())
print(f"\nTotal unique crops: {df['label'].nunique()}")

# Filter for Rwanda-relevant crops (case-insensitive matching)
df_filtered = df[df['label'].str.lower().isin([crop.lower() for crop in RWANDA_CROPS])].copy()

print("\n" + "="*80)
print(f" Filtered dataset: {len(df_filtered):,} records retained ({len(df_filtered)/len(df)*100:.1f}%)")
print(f" Removed: {len(df) - len(df_filtered):,} records")
print("\nFiltered Crop Distribution:")
print(df_filtered['label'].value_counts())

# Update working dataframe
df = df_filtered.copy()
# Out:
# ...
# FILTERING CROPS RELEVANT TO RWANDA
# ...
#
# Original Crop Distribution:
# label
# Teff          1260
# Maize          732
# Wheat          715
# Barley         503
# Bean           253
# Pea             94
# Sorghum         72
# Dagussa         71
# Niger seed      64
# Potato          48
# Red Pepper      29
# Fallow          26
# Name: count, dtype: int64
#
# Total unique crops: 12
#
# ...
#  Filtered dataset: 1,820 records retained (47.1%)
#  Removed: 2,047 records
#
# Filtered Crop Distribution:
# label
# Maize      732
# Wheat      715
# Bean       253
# Sorghum     72
# Potato      48
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Exploratory Data Analysis (EDA)

# %%
print("\n" + "="*80)
print("EXPLORATORY DATA ANALYSIS")
print("="*80)
# Out:
# ...
# EXPLORATORY DATA ANALYSIS
# ...

# %%
# 5.1 Target Variable Distribution
plt.figure(figsize=(14, 6))
crop_counts = df['label'].value_counts()
plt.subplot(1, 2, 1)
crop_counts.plot(kind='bar', color='steelblue', edgecolor='black')
plt.title('Crop Distribution in Dataset', fontsize=14, fontweight='bold')
plt.xlabel('Crop Type', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.3)

# %%
plt.subplot(1, 2, 2)
plt.pie(crop_counts, labels=crop_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Crop Proportion', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('crop_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Most common crop: {crop_counts.index[0]} ({crop_counts.iloc[0]} samples)")
print(f" Least common crop: {crop_counts.index[-1]} ({crop_counts.iloc[-1]} samples)")
# Out:
#  Most common crop: Maize (732 samples)
#  Least common crop: Potato (48 samples)

# %%
# 5.2 Soil Parameter Distributions
soil_params = ['Ph', 'N', 'P', 'K', 'Zn', 'S']

fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.ravel()

for idx, param in enumerate(soil_params):
    axes[idx].hist(df[param], bins=30, color='coral', edgecolor='black', alpha=0.7)
    axes[idx].axvline(df[param].mean(), color='red', linestyle='--',
                      linewidth=2, label=f'Mean: {df[param].mean():.2f}')
    axes[idx].set_title(f'{param} Distribution', fontsize=12, fontweight='bold')
    axes[idx].set_xlabel(param, fontsize=10)
    axes[idx].set_ylabel('Frequency', fontsize=10)
    axes[idx].legend()
    axes[idx].grid(alpha=0.3)

plt.tight_layout()
plt.savefig('soil_parameters_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# 5.3 Correlation Analysis
# Select only numerical columns for correlation
numerical_cols = df.select_dtypes(include=[np.number]).columns.tolist()

plt.figure(figsize=(16, 12))
correlation_matrix = df[numerical_cols].corr()
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm',
            center=0, square=True, linewidths=1, cbar_kws={"shrink": 0.8})
plt.title('Correlation Heatmap of Soil and Climate Features',
          fontsize=14, fontweight='bold', pad=20)
plt.tight_layout()
plt.savefig('correlation_heatmap.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# 5.4 Soil pH vs Crop Type (Critical for Rwanda's lateritic soils)
plt.figure(figsize=(14, 6))
df.boxplot(column='Ph', by='label', ax=plt.gca(), patch_artist=True)
plt.title('Soil pH Requirements by Crop Type\n(Critical for Rwanda Lateritic Soils)',
          fontsize=14, fontweight='bold')
plt.suptitle('')  # Remove default title
plt.xlabel('Crop Type', fontsize=12)
plt.ylabel('pH Level', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.axhline(y=5.5, color='r', linestyle='--', label='Acidic Soil Threshold')
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig('ph_by_crop.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# 5.5 Key Nutrient Analysis (N, P, K)
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for idx, nutrient in enumerate(['N', 'P', 'K']):
    df.boxplot(column=nutrient, by='label', ax=axes[idx], patch_artist=True)
    axes[idx].set_title(f'{nutrient} Requirements by Crop', fontsize=12, fontweight='bold')
    axes[idx].set_xlabel('Crop Type', fontsize=10)
    axes[idx].set_ylabel(f'{nutrient} Content', fontsize=10)
    axes[idx].tick_params(axis='x', rotation=45)

plt.suptitle('NPK Nutrient Requirements Analysis', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('npk_analysis.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 6. Data Preprocessing

# %%
print("\n" + "="*80)
print("DATA PREPROCESSING")
print("="*80)
# Out:
# ...
# DATA PREPROCESSING
# ...

# %%
# 6.1 Remove unnecessary columns
# Drop Soilcolor as it's not a quantitative measure and may introduce bias
columns_to_drop = ['Soilcolor']
df_processed = df.drop(columns=columns_to_drop, errors='ignore')
print(f"\n✓ Dropped columns: {columns_to_drop}")
# Out:
# ✓ Dropped columns: ['Soilcolor']

# %%
# 6.2 Separate features and target
X = df_processed.drop('label', axis=1)
y = df_processed['label']

print(f"\n Feature matrix shape: {X.shape}")
print(f" Target vector shape: {y.shape}")
print(f" Number of classes: {y.nunique()}")
# Out:
#  Feature matrix shape: (1820, 27)
#  Target vector shape: (1820,)
#  Number of classes: 5

# %%
# 6.3 Encode target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

print("\n" + "-"*80)
print("Crop Label Encoding:")
for idx, crop in enumerate(label_encoder.classes_):
    print(f"  {crop}: {idx}")
# Out:
# --------------------------------------------------------------------------------
# Crop Label Encoding:
#   Bean: 0
#   Maize: 1
#   Potato: 2
#   Sorghum: 3
#   Wheat: 4

# %%
# 6.4 Handle class imbalance
class_distribution = pd.Series(y_encoded).value_counts()
imbalance_ratio = class_distribution.max() / class_distribution.min()

print(f"\nClass Imbalance Ratio: {imbalance_ratio:.2f}")
if imbalance_ratio > 3:
    print(" Significant class imbalance detected. Consider using class_weight='balanced' in models.")# 6.5 Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

print(f"\n Training set: {X_train.shape[0]:,} samples ({X_train.shape[0]/len(X)*100:.1f}%)")
print(f" Testing set: {X_test.shape[0]:,} samples ({X_test.shape[0]/len(X)*100:.1f}%)")
# Out:
# Class Imbalance Ratio: 15.25
#  Significant class imbalance detected. Consider using class_weight='balanced' in models.
#
#  Training set: 1,456 samples (80.0%)
#  Testing set: 364 samples (20.0%)

# %%
# 6.5 Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded
)

print(f"\n Training set: {X_train.shape[0]:,} samples ({X_train.shape[0]/len(X)*100:.1f}%)")
print(f" Testing set: {X_test.shape[0]:,} samples ({X_test.shape[0]/len(X)*100:.1f}%)")
# Out:
#  Training set: 1,456 samples (80.0%)
#  Testing set: 364 samples (20.0%)

# %%
# 6.6 Feature Scaling (important for distance-based algorithms)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("\n Feature scaling completed using StandardScaler")
print(f"  Mean of scaled features: {X_train_scaled.mean():.2e}")
print(f"  Std of scaled features: {X_train_scaled.std():.2f}")
# Out:
#  Feature scaling completed using StandardScaler
#   Mean of scaled features: -2.52e-16
#   Std of scaled features: 1.00

# %% [markdown]
# ## 7. Model Selection & Training

# %%
print("\n" + "="*80)
print("MODEL TRAINING")
print("="*80)

# %%
# Initialize models suitable for multi-class classification
models = {
    'Random Forest': RandomForestClassifier(random_state=42, n_jobs=-1, class_weight='balanced'),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42),
    'Decision Tree': DecisionTreeClassifier(random_state=42, class_weight='balanced'),
    'K-Nearest Neighbors': KNeighborsClassifier(n_jobs=-1),
    'Logistic Regression': LogisticRegression(random_state=42, max_iter=1000,
                                              class_weight='balanced', multi_class='multinomial')
}

# Train and evaluate each model
results = {}

for name, model in models.items():
    print(f"\nTraining {name}...")

    # Use scaled data for KNN and Logistic Regression
    if name in ['K-Nearest Neighbors', 'Logistic Regression']:
        model.fit(X_train_scaled, y_train)
        y_pred = model.predict(X_test_scaled)
    else:
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

    # Calculate metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='weighted')

    results[name] = {
        'model': model,
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'predictions': y_pred
    }

    print(f" Accuracy: {accuracy:.4f}")
    print(f" Precision: {precision:.4f}")
    print(f" Recall: {recall:.4f}")
    print(f" F1-Score: {f1:.4f}")
# Out:
# ...
# MODEL TRAINING
# ...
#
# Training Random Forest...
#  Accuracy: 0.6621
#  Precision: 0.6467
#  Recall: 0.6621
#  F1-Score: 0.6397
#
# Training Gradient Boosting...
#  Accuracy: 0.6236
#  Precision: 0.5928
#  Recall: 0.6236
#  F1-Score: 0.5903
#
# Training Decision Tree...
#  Accuracy: 0.5192
#  Precision: 0.5291
#  Recall: 0.5192
#  F1-Score: 0.5237
#
# Training K-Nearest Neighbors...
#  Accuracy: 0.6484
#  Precision: 0.6333
#  Recall: 0.6484
#  F1-Score: 0.6366
#
# Training Logistic Regression...
#  Accuracy: 0.4560
#  Precision: 0.6740
#  Recall: 0.4560
#  F1-Score: 0.5159

# %% [markdown]
# ## 8. Model Evaluation

# %%
print("\n" + "="*80)
print("MODEL EVALUATION & COMPARISON")
print("="*80)
# Out:
# ...
# MODEL EVALUATION & COMPARISON
# ...

# %%
# 8.1 Compare model performance
comparison_df = pd.DataFrame({
    'Model': results.keys(),
    'Accuracy': [v['accuracy'] for v in results.values()],
    'Precision': [v['precision'] for v in results.values()],
    'Recall': [v['recall'] for v in results.values()],
    'F1-Score': [v['f1_score'] for v in results.values()]
})

comparison_df = comparison_df.sort_values('Accuracy', ascending=False).reset_index(drop=True)
print("\n", comparison_df.to_string(index=False))

# Identify best model
best_model_name = comparison_df.iloc[0]['Model']
best_model = results[best_model_name]['model']
best_predictions = results[best_model_name]['predictions']

print(f"\n{'='*80}")
print(f" BEST PERFORMING MODEL: {best_model_name}")
print(f"   Accuracy: {comparison_df.iloc[0]['Accuracy']:.4f}")
print(f"{'='*80}")
# Out:
#                Model  Accuracy  Precision   Recall  F1-Score
#       Random Forest  0.662088   0.646683 0.662088  0.639679
# K-Nearest Neighbors  0.648352   0.633335 0.648352  0.636575
#   Gradient Boosting  0.623626   0.592752 0.623626  0.590332
#       Decision Tree  0.519231   0.529105 0.519231  0.523665
# Logistic Regression  0.456044   0.673958 0.456044  0.515920
#
# ...
#  BEST PERFORMING MODEL: Random Forest
#    Accuracy: 0.6621
# ...

# %%
# 8.2 Visualize model comparison
fig, ax = plt.subplots(figsize=(12, 6))
x = np.arange(len(comparison_df))
width = 0.2

metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score']
colors = ['steelblue', 'coral', 'lightgreen', 'gold']

for idx, (metric, color) in enumerate(zip(metrics, colors)):
    offset = width * (idx - 1.5)
    ax.bar(x + offset, comparison_df[metric], width, label=metric, color=color, edgecolor='black')

ax.set_xlabel('Models', fontsize=12, fontweight='bold')
ax.set_ylabel('Score', fontsize=12, fontweight='bold')
ax.set_title('Model Performance Comparison', fontsize=14, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(comparison_df['Model'], rotation=15, ha='right')
ax.legend(loc='lower right')
ax.grid(axis='y', alpha=0.3)
ax.set_ylim([0, 1.1])

plt.tight_layout()
plt.savefig('model_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# 8.3 Detailed classification report for best model
print(f"\n{'='*80}")
print(f"DETAILED CLASSIFICATION REPORT - {best_model_name}")
print(f"{'='*80}\n")
print(classification_report(y_test, best_predictions,
                          target_names=label_encoder.classes_))
# Out:
# ...
# DETAILED CLASSIFICATION REPORT - Random Forest
# ...
#
#               precision    recall  f1-score   support
#
#         Bean       0.46      0.25      0.33        51
#        Maize       0.77      0.78      0.77       146
#       Potato       0.20      0.10      0.13        10
#      Sorghum       0.67      0.14      0.24        14
#        Wheat       0.62      0.78      0.69       143
#
#     accuracy                           0.66       364
#    macro avg       0.54      0.41      0.43       364
# weighted avg       0.65      0.66      0.64       364

# %%
# 8.4 Confusion Matrix
cm = confusion_matrix(y_test, best_predictions)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=label_encoder.classes_,
            yticklabels=label_encoder.classes_,
            cbar_kws={'label': 'Count'})
plt.title(f'Confusion Matrix - {best_model_name}', fontsize=14, fontweight='bold', pad=20)
plt.xlabel('Predicted Crop', fontsize=12)
plt.ylabel('Actual Crop', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.savefig('confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# 8.5 Feature Importance (for tree-based models)
if best_model_name in ['Random Forest', 'Gradient Boosting', 'Decision Tree']:
    feature_importance = pd.DataFrame({
        'Feature': X.columns,
        'Importance': best_model.feature_importances_
    }).sort_values('Importance', ascending=False)

    print(f"\n{'='*80}")
    print(f"TOP 10 MOST IMPORTANT FEATURES - {best_model_name}")
    print(f"{'='*80}\n")
    print(feature_importance.head(10).to_string(index=False))

    plt.figure(figsize=(12, 8))
    top_features = feature_importance.head(15)
    plt.barh(top_features['Feature'], top_features['Importance'], color='teal', edgecolor='black')
    plt.xlabel('Importance Score', fontsize=12)
    plt.ylabel('Feature', fontsize=12)
    plt.title(f'Top 15 Feature Importances - {best_model_name}',
              fontsize=14, fontweight='bold')
    plt.gca().invert_yaxis()
    plt.grid(axis='x', alpha=0.3)
    plt.tight_layout()
    plt.savefig('feature_importance.png', dpi=300, bbox_inches='tight')
    plt.show()
# Out:
# ...
# TOP 10 MOST IMPORTANT FEATURES - Random Forest
# ...
#
#        Feature  Importance
#              K    0.141885
#             Ph    0.137771
#              P    0.131787
#              N    0.124537
#             Zn    0.119027
#              S    0.112015
# PRECTOTCORR-Su    0.020320
#        QV2M-Su    0.018093
#     T2M_MAX-Sp    0.015196
#     T2M_MIN-Su    0.014734

# %% [markdown]
# ## 9. Hyperparameter Tuning

# %%
print("\n" + "="*80)
print("HYPERPARAMETER TUNING")
print("="*80)

# Define parameter grid for the best model
if best_model_name == 'Random Forest':
    param_grid = {
        'n_estimators': [100, 200, 300],
        'max_depth': [10, 20, 30, None],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['sqrt', 'log2']
    }

    print(f"\nTuning Random Forest with GridSearchCV...")
    print("This may take several minutes...")

    # Use scaled or unscaled data based on model type
    X_train_tuning = X_train
    X_test_tuning = X_test

elif best_model_name == 'Gradient Boosting':
    param_grid = {
        'n_estimators': [100, 200, 300],
        'learning_rate': [0.01, 0.1, 0.2],
        'max_depth': [3, 5, 7],
        'min_samples_split': [2, 5, 10],
        'subsample': [0.8, 0.9, 1.0]
    }

    print(f"\nTuning Gradient Boosting with GridSearchCV...")
    print("This may take several minutes...")

    X_train_tuning = X_train
    X_test_tuning = X_test

elif best_model_name == 'K-Nearest Neighbors':
    param_grid = {
        'n_neighbors': [3, 5, 7, 9, 11],
        'weights': ['uniform', 'distance'],
        'metric': ['euclidean', 'manhattan', 'minkowski']
    }

    print(f"\nTuning K-Nearest Neighbors with GridSearchCV...")

    X_train_tuning = X_train_scaled
    X_test_tuning = X_test_scaled

else:
    print(f"\nSkipping hyperparameter tuning for {best_model_name}")
    param_grid = None
    X_train_tuning = X_train
    X_test_tuning = X_test

# Perform Grid Search if applicable
if param_grid:
    # Create fresh model instance
    if best_model_name == 'Random Forest':
        base_model = RandomForestClassifier(random_state=42, n_jobs=-1, class_weight='balanced')
    elif best_model_name == 'Gradient Boosting':
        base_model = GradientBoostingClassifier(random_state=42)
    elif best_model_name == 'K-Nearest Neighbors':
        base_model = KNeighborsClassifier(n_jobs=-1)

    # Grid search with cross-validation
    grid_search = GridSearchCV(
        estimator=base_model,
        param_grid=param_grid,
        cv=5,
        scoring='accuracy',
        n_jobs=-1,
        verbose=1
    )

    grid_search.fit(X_train_tuning, y_train)

    print(f"\n Grid Search completed")
    print(f"\nBest Parameters:")
    for param, value in grid_search.best_params_.items():
        print(f"  {param}: {value}")

    print(f"\nBest Cross-Validation Score: {grid_search.best_score_:.4f}")

    # Evaluate tuned model
    tuned_model = grid_search.best_estimator_
    y_pred_tuned = tuned_model.predict(X_test_tuning)
    tuned_accuracy = accuracy_score(y_test, y_pred_tuned)

    print(f"\nPerformance Comparison:")
    print(f"  Original Model Accuracy: {results[best_model_name]['accuracy']:.4f}")
    print(f"  Tuned Model Accuracy: {tuned_accuracy:.4f}")
    print(f"  Improvement: {(tuned_accuracy - results[best_model_name]['accuracy']):.4f}")

    # Use tuned model as final model
    final_model = tuned_model
else:
    final_model = best_model
# Out:
# ...
# HYPERPARAMETER TUNING
# ...
#
# Tuning Random Forest with GridSearchCV...
# This may take several minutes...
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits

# %% [markdown]
# ## 10. Result Interpretation

# %%
print("\n" + "="*80)
print("RESULT INTERPRETATION & INSIGHTS")
print("="*80)

print("\n KEY FINDINGS FOR RWANDA SOIL QUALITY MONITORING:\n")

# %%
# 1. Model Performance Insights
print("1. MODEL PERFORMANCE:")
print(f"  Best Model: {best_model_name}")
print(f"  Accuracy: {comparison_df.iloc[0]['Accuracy']*100:.2f}%")
print(f"  This model can predict the most suitable crop with high confidence")
print(f"  Recommended for deployment in the pilot phase\n")

# %%
# 2. Soil Parameter Insights
if best_model_name in ['Random Forest', 'Gradient Boosting', 'Decision Tree']:
    top_3_features = feature_importance.head(3)
    print("2. CRITICAL SOIL PARAMETERS FOR RWANDA:")
    for idx, row in top_3_features.iterrows():
        print(f"   • {row['Feature']}: {row['Importance']:.4f} importance")
    print(" Farmers should prioritize monitoring these parameters\n")

# %%
# 3. pH Analysis for Lateritic Soils
print("3. SOIL pH RECOMMENDATIONS:")
mean_ph = df['Ph'].mean()
print(f"   • Average soil pH in dataset: {mean_ph:.2f}")
if mean_ph < 5.5:
    print("  ALERT: Acidic soils detected (common in Rwanda)")
    print("  Recommend lime application to raise pH")
    print("  Target pH range: 6.0-7.0 for most crops")
else:
    print("  Soil pH generally suitable for cultivation")
print()

# %%
# 4. Nutrient Recommendations
print("4. NUTRIENT MANAGEMENT INSIGHTS:")
for nutrient in ['N', 'P', 'K']:
    mean_val = df[nutrient].mean()
    print(f" Average {nutrient}: {mean_val:.2f}")
print(" Use these baselines to guide fertilizer recommendations")
print(" Adjust based on specific crop requirements\n")

# %%
# 5. Crop Diversity
print("5. CROP DIVERSIFICATION POTENTIAL:")
print(f" Dataset supports {y.nunique()} different crops")
print(f" Top 3 crops: {', '.join(crop_counts.head(3).index.tolist())}")
print(" Model can guide farmers on alternative crop options")
print(" Supports climate-smart crop rotation strategies\n")

# %%
# 6. Practical Recommendations
print("6. IMPLEMENTATION RECOMMENDATIONS:")
print(" Deploy system with top 3-5 most common crops initially")
print(" Collect local soil samples to improve model accuracy")
print(" Integrate with weather data for seasonal recommendations")
print(" Provide SMS-based recommendations for farmers without smartphones")
print(" Train extension workers to interpret model outputs\n")

# %%
# 7. Limitations and Future Work
print("7. LIMITATIONS & FUTURE IMPROVEMENTS:")
print(" Model trained on general data - needs Rwanda-specific calibration")
print(" Consider adding: rainfall patterns, temperature, elevation")
print(" Pilot testing needed with 10-15 farmers in Kamonyi/Rwamagana")
print(" Collect feedback to refine recommendations")
print(" Expand to include organic fertilizer recommendations\n")

# %% [markdown]
# ## 11. Model Saving

# %%
print("="*80)
print("MODEL PERSISTENCE")
print("="*80)

# %%
# Save the trained model
model_filename = f'rwanda_soil_model_{best_model_name.replace(" ", "_").lower()}.pkl'
joblib.dump(final_model, model_filename)
print(f"\n Model saved as: {model_filename}")

# %%
# Save the scaler
scaler_filename = 'feature_scaler.pkl'
joblib.dump(scaler, scaler_filename)
print(f" Scaler saved as: {scaler_filename}")

# %%
# Save the label encoder
encoder_filename = 'label_encoder.pkl'
joblib.dump(label_encoder, encoder_filename)
print(f" Label encoder saved as: {encoder_filename}")

# %%
# Save feature names
feature_names = X.columns.tolist()
with open('feature_names.pkl', 'wb') as f:
    pickle.dump(feature_names, f)
print(f" Feature names saved as: feature_names.pkl")

# %%
# Create a metadata file
metadata = {
    'model_name': best_model_name,
    'accuracy': float(comparison_df.iloc[0]['Accuracy']),
    'n_features': len(X.columns),
    'n_classes': len(label_encoder.classes_),
    'classes': label_encoder.classes_.tolist(),
    'training_samples': len(X_train),
    'test_samples': len(X_test),
    'date_trained': pd.Timestamp.now().strftime('%Y-%m-%d %H:%M:%S')
}

# %%
import json
with open('model_metadata.json', 'w') as f:
    json.dump(metadata, f, indent=4)
print(f" Metadata saved as: model_metadata.json")

print("\n" + "="*80)
print("MODEL LOADING EXAMPLE")
print("="*80)
print("""
# To load and use the model later:

import joblib
import pandas as pd

# Load model and preprocessors
model = joblib.load('""" + model_filename + """')
scaler = joblib.load('feature_scaler.pkl')
label_encoder = joblib.load('label_encoder.pkl')

# Prepare new data (must match training features)
new_data = pd.DataFrame({
    'Ph': [6.5], 'N': [40], 'P': [20], 'K': [200],
    # ... include all features
})

# Scale if needed (for KNN, Logistic Regression)
# new_data_scaled = scaler.transform(new_data)

# Make prediction
prediction_encoded = model.predict(new_data)
prediction = label_encoder.inverse_transform(prediction_encoded)
print(f"Recommended crop: {prediction[0]}")
""")

print("\n" + "="*80)
print(" ANALYSIS COMPLETE!")
